# %%
import cv2
import numpy as np

# %%
def cam(w, h, link, login=None, password=None):
    if '.mp4' in link:
        new_link=link
    else:
        sign=':'
        l_p=''.join([login,sign,password])
        # Найдем начальную и конечную позиции символа "@"
        start_position = link.index("rtsp://") + len("rtsp://")
        end_position = link.index("@")
        new_link = link.replace(link[start_position:end_position], l_p)
    print(new_link)
    cap = cv2.VideoCapture(new_link) 
    # Check if camera opened successfully
    if (cap.isOpened()== False): 
        print("Error opening video stream or file")
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret == True:
            frame = cv2.resize(frame, (w,h))
            cv2.imshow('Frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
link1='rtsp://rtsp:Rtsp1234@188.170.176.190:8027/Streaming/Channels/101?transportmode=unicast&profile=Profile_1'
link2='rtsp://rtsp:Rtsp1234@188.170.176.190:8028/Streaming/Channels/101?transportmode=unicast&profile=Profile_1'
link3='rtsp://rtsp:Rtsp1234@188.170.176.190:8029/Streaming/Channels/101?transportmode=unicast&profile=Profile_1'
link4='rtsp://rtsp:Rtsp1234@188.170.176.190:8030/Streaming/Channels/101?transportmode=unicast&profile=Profile_1'
link5='rtsp://rtsp:Rtsp1234@188.170.176.190:8031/Streaming/Channels/101?transportmode=unicast&profile=Profile_1'

# %%
cam(1920, 1080, link4, 'admin', 'A1234567')
# Out:
# rtsp://admin:A1234567@188.170.176.190:8030/Streaming/Channels/101?transportmode=unicast&profile=Profile_1
# Error opening video stream or file

# %%
rtsp://rtsp:Rtsp1234@188.170.176.190:8031/Streaming/Channels/101?transportmode=unicast&profile=Profile_1

# %%
# Out:
# 0

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('runs/detect/train2/weights/best.pt')

# Open the video file
video_path = "61_VC8_2_4_Парковая_67_2_эт_2023_11_03_15_30_00_000+0300_5m0s.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True, verbose=False)
        
        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\SVA\AppData\Roaming\Python\Python310\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (2.0.7) or chardet (None)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
#
# 0: 384x640 (no detections), 92.0ms
# Speed: 8.0ms preprocess, 92.0ms inference, 58.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
from ultralytics import YOLO
import time

# Load the YOLOv8 model
model = YOLO('runs/detect/train5/weights/best.pt')

# Open the video file
video_path = "61_VC8_2_4_Парковая_67_2_эт_2023_11_03_15_30_00_000+0300_5m0s.mp4"
cap = cv2.VideoCapture(video_path)
# cap = cv2.VideoCapture(0)

# Create a video writer to save the annotated video
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Initialize a list to store the results
results_list = []
results_frames = []

# Loop through the video frames
start_time = time.time()
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True, verbose=False)

        if len(results[0].boxes) > 1:
            
            if results[0].boxes.conf[0].item() > 0.8 and results[0].boxes.conf[1].item() > 0.5:
            
                # Append the results to the list
                results_list.append(time.time() - start_time)
            
                # Visualize the results on the frame
                annotated_frame = results[0].plot()
                results_frames.append(annotated_frame)

        else:

            annotated_frame = frame.copy()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object, video writer, and close the display window
end_time = time.time()
cap.release()
cv2.destroyAllWindows()

# Print the start and end time of object detection
print("Start time:", start_time)
print("End time:", end_time)

# Print the results list
print("Results:", results_list)
# Out:
# Start time: 1699732530.173354
# End time: 1699732643.6670547
# Results: [6.336224555969238, 6.446224689483643, 6.483224868774414, 6.7127110958099365, 6.751361131668091, 6.7883594036102295, 6.82435941696167, 6.863360166549683, 6.9023425579071045, 7.8888349533081055, 50.39102625846863, 50.458027601242065, 50.49202585220337, 89.55209612846375, 112.48946642875671]

# %%
# Out:
# tensor(0.7487, device='cuda:0')
