# %%
from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train2/weights/best.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='yolo_data/data.yaml', epochs=50, imgsz=640, batch=64)
# Out:
# Ultralytics YOLOv8.0.208  Python-3.10.13 torch-2.2.0.dev20231110+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train4/weights/best.pt')

# Export the model
model.export(format='onnx', opset=12)
# Out:
# Ultralytics YOLOv8.0.208  Python-3.10.13 torch-2.2.0.dev20231110+cu121 CPU (13th Gen Intel Core(TM) i7-13700KF)
# YOLOv5s summary (fused): 193 layers, 9112310 parameters, 0 gradients, 23.8 GFLOPs
#
# PyTorch: starting from 'runs\detect\train4\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (17.7 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 12...
# ONNX: export success  0.9s, saved as 'runs\detect\train4\weights\best.onnx' (35.0 MB)
#
# Export complete (2.5s)
# Results saved to D:\code\champs\lct_krasnodar\runs\detect\train4\weights
# Predict:         yolo predict task=detect model=runs\detect\train4\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train4\weights\best.onnx imgsz=640 data=yolo_data/data.yaml
# Visualize:       https://netron.app
# 'runs\\detect\\train4\\weights\\best.onnx'

# %%
#
